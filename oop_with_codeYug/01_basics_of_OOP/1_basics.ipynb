# %% [markdown]
# ### What is Object-Oriented Programming(OOP)?

# %% [markdown]
# * Object-oriented programming is an approach of writing programs by creating classes and objects.
# * More focus is on `data` rather than `logic`.
# * Its Way of organizing programs.
#
# Python supports multiple paradigms. These are as follows :-
#
# 1) Procedural oriented paradigm
# 2) Functional oriented paradigm
# 3) Object-oriented paradigm

# %% [markdown]
# ### Why OOP?

# %% [markdown]
# * To solve real-world problems effectively.
# * OOP provides some features :-
# 1) Inheritance :- `reusability`
# 2) encapsulation :- `data security`
# 3) abstraction :- `Data hiding`

# %% [markdown]
# ### What is Class in OOP?

# %% [markdown]
# * Class is a template/blueprint/prototype for creating objects.
# * Every object belongs to some class.
# * class is a collection of attributes and behaviours.
# * technically, class is a user-defined data type.
# * Email class :- email1 + email2 + email3 +email4
#
# It tells that whenever we create an email object, it should have some attributes and behaviours. It is a template for creating objects. So, email instance attributes and behaviours will be different from ueage by usage.

# %%
# some builtint data types of Python classes are:

l1: list[int] = [1, 2, 3]
s1: str = "hello world"
t1 = (1, 2, 3)


def func() -> None:
    pass


print(type(l1), type(s1), type(t1), type(func))
# Out:
# <class 'list'> <class 'str'> <class 'tuple'> <class 'function'>

# %%
# user defined datatypes:
class Student:
    pass


class Car:
    pass


st = Student()
cr = Car()

print(type(st), type(cr))
# this __main__ tells that this class is in current module.
# Out:
# <class '__main__.Student'> <class '__main__.Car'>

# %% [markdown]
# ### What is an Object in OOP?

# %% [markdown]
# * An object in OOP represents real-life objects. ex. Email, man, student, employee etc
# * Every object has two properties.
#
# 1) Attributes (means Data) -> heading,subject,name, recipients list of an Email Object
# 2) Behaviours (means Actions or Functions) -> sending,Adding attachments, deleting etc of an Email Object

# %% [markdown]
# ### Creating Class and Object in Python

# %% [markdown]
# ```python
# # creating a class
# class Class_name:
#     #attributes
#     #methods
#     pass
#
# obj = Class_name([args]) # creating an object
# ```

# %% [markdown]
# ### Constructor & types of Constructor

# %% [markdown]
# * Special method which is used for initializing objects with attributes
# * Initialize default values of the object, at the time of creation.
# * it is __init__ method
# * First argument is `self`
#
# There are 3 types of constructors in Python :-
#
# * Parameterized constructor
# * Non-Parameterized constructor
# * Default Constructor
#
# without constructor:- Object cannot be created.So, in that case default constructor will be called.

# %% [markdown]
# #### example of non-parameterized constructor

# %%
class Employee:
    def __init__(self) -> None:
        self.age = 21
        self.salary = 10000

# %%
e1: Employee = Employee()  # example of non-parameterized constructor
e2: Employee = Employee()  # example of non-parameterized constructor

print(e1.__dict__)
print(e2.__dict__)
# Out:
# {'age': 21, 'salary': 10000}
# {'age': 21, 'salary': 10000}

# %% [markdown]
# #### example of parameterized constructor

# %%
class Employee:
    def __init__(self, age: int, salary: int) -> None:
        self.age: int = age
        self.salary: int = salary

# %%
e1: Employee = Employee(26, 25000)  # example of parameterized constructor
e2: Employee = Employee(24, 35000)  # example of parameterized constructor

print(e1.__dict__)
print(e2.__dict__)
# Out:
# {'age': 26, 'salary': 25000}
# {'age': 24, 'salary': 35000}

# %% [markdown]
# #### example of default constructor

# %%
class Employee:
    pass

# %%
e1: Employee = Employee()
e2: Employee = Employee()

print(e1.__dict__)
print(e2.__dict__)
# Out:
# {}
# {}

# %% [markdown]
# ### Working of OOP and `self` variable

# %% [markdown]
# [Lecture Explaination](https://youtu.be/KCPqvyvZKmw?si=V7tV9n1qnHxW_pZV)
#
# `self` is a reference number(let's say its 2734) which is used to refer to the current instance(obj) of the class in the memory. It is automatically passed to the instance methods of the class, when we initiate an object of the class. It allows us to access the attributes and methods of the class within its own scope.
#
# so when we do `obj.attribute` or `2734.salary`, it means that program goes to the memory location of `obj-2734` and create a variable named `salary` and assign it `the value`, `the value` is what `we defined as default` or we `take it from user`.
#
# so when we do `e2.Employe()`, it will create a memory location for `e2`. then, when we do `e2.salary`, it will go to that memory location of `e2` and create a variables named `salary` and assign it the value. so `self` will get the `e2` memory number and `salary` variable got its value.
#
# through this we get our values.

# %% [markdown]
# 1. memory allocation for object
# 2. memory reference returned to the object
# 3. memory reference automatically passsed inside constructor.
# 4. constructor creates/intiialize variables at that memory reference
# 5. What is `Self`:- it is just a variable, which hold the memory address of the current object.So, that the class knows on whihc object its working on, means it can know that in which memory location it has to create the variables and assign values. becuase its varibale, so we can use any name.

# %%
class Employee:
    pass


e1: Employee = Employee()
e2: Employee = Employee()

print(e1.__dict__)
#  print("e1 id:", id(e1))
print(e2.__dict__)
#  print("e1 id:", id(e1))

print("e1 id:", hex(id(e1)))
print("e2 id:", hex(id(e2)))
# Out:
# {}
# {}
# e1 id: 0x2b5d45edfd0
# e2 id: 0x2b5d4432990

# %% [markdown]
# ### How to access class members?

# %% [markdown]
# * Class members :- Attributes(variables, data) + Actions(Methods, functions)
# * We can access these variables using object outside the class.
#
# ```python
# Syntax :-
# Accessing attribute :- object_name.variable_name
# Accessing method :- object_name.method_name()
# ```
#
# [Lecture](https://youtu.be/YDWSCFge0ic?si=Vb2VnX3prIfwawoD)

# %%
class Employee:
    def __init__(self, age: int, salary: int) -> None:
        self.age: int = age
        self.salary: int = salary

    def display(self) -> str:
        return f"Your age is: {self.age} and current salary is: {self.salary}"


e1: Employee = Employee(26, 25000)
e2: Employee = Employee(24, 35000)

# it will go into the memory address of il, and get the value of age variable.
print(e1.age)

# it will go into the memory address of e1, and get the value of salary variable.
print(e1.salary)

# we can update the value of variable inside the memory
e1.salary = 75000
print(e1.salary)


# so this e1 memory reference automatically pass in the method() as we have write self for this. there it find the memoery reference of obj(e1 or e2) and execute the method(display) for that object.
print(e1.display())

print(e2.display())  # Your age is: 24 and current salary is: 35000
# Out:
# 26
# 25000
# 75000
# Your age is: 26 and current salary is: 75000
# Your age is: 24 and current salary is: 35000

# %% [markdown]
# ### Builtin Class Functions for OOP

# %% [markdown]
# By using these functions, we can `manipulate the data of objects` in a more dynamic way. These functions allow us to check for the existence of attributes, set new values, and delete attributes from objects.
#
# * [Lecture](https://youtu.be/Ua9blALSlKU?si=Kc8TgeWyfuTnhFnN)
#
# Following are built-in class functions :-
#
# * getattr(object_name, attribute_name)
# * setattr(object_name, attribute_name, new_value)
# * delattr(object_name, attribute_name)
# * hasattr(object_name, attribute_name) -> Returns True or False based on whether the object has the specified attribute.

# %%
class Employee:
    def __init__(self, name: str, age: int) -> None:
        self.name: str = name
        self.age: int = age


e1 = Employee('raj', 21)
e2 = Employee('jay', 22)

print(getattr(e1, 'age'))  # 21

setattr(e2, 'name', 'jayraj')
print(e2.__dict__)

delattr(e2, 'age')
print(e2.__dict__)

print(hasattr(e1, 'age'))
print(hasattr(e2, 'age'))
# Out:
# 21
# {'name': 'jayraj', 'age': 22}
# {'name': 'jayraj'}
# True
# False

# %% [markdown]
# ### Builtin Class attributes

# %% [markdown]
# * [Leccture](https://youtu.be/-DwxchTg0VU?si=J-wmS-97WnRjcc8L)
#
# whenever we ceate a python class or object, python automatically creates some attributes for that class or object. These attributes are called built-in class attributes. These attributes provide information about the class or object and can be accessed using the dot notation.
#
# Following are built-in class attributes :-
#
# * __dict__ :- Dictionary containing class's namespace
#
# * __doc__ :- Class documentation string.
#
# * __name__ :- Class Name
#
# * __module__ :- Module name in which class is defined
#
# * __bases__ :- List of base classes

# %%
class Employee:
    '''
    This is employee class, for maintaining the Employee data.
    '''

    def __init__(self, name: str, age: int) -> None:
        self.name: str = name
        self.age: int = age


e1 = Employee('raj', 21)
e2 = Employee('jay', 22)

print(Employee.__doc__)
print(Employee.__dict__)
# for example we are writing any condition, where we need the name of that class, so we will use it.
print(Employee.__name__)
# Out:
# This is employee class, for maintaining the Employee data.
#
# {'__module__': '__main__', '__firstlineno__': 1, '__doc__': '\nThis is employee class, for maintaining the Employee data.\n', '__init__': <function Employee.__init__ at 0x000002B5D48494E0>, '__static_attributes__': ('age', 'name'), '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>}
